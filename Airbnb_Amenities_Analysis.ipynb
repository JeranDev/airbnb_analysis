# %% [markdown]
# # Airbnb Amenities Analysis
# ⌨ Jeran Burget
#
# This analysis explores different amenities offered in Airbnb listings in Salem, Oregon. The objective of this analysis is to determine which amenities in Salem are the most common, and which ones are the least commonly observed.
#
# ## About the data
# This data set `airbnb.csv` comes from the Airbnb website and describes about 300 Airbnb listings in the Salem, Oregon area. The data describes many aspects of the listings including information about the hosts, listing description, and amenities offered at the facilities.
#
# ## Analysis
# The goal of this analysis is to determine which amenities are the most common and which are the least common in the Salem, Oregon area. However, because the amenities are stored as lists in a single column of the data set, this information is difficult to analyze without the use of for loops.

# %%
import pandas as pd
df = pd.read_csv('airbnb.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  302 non-null    object
#  1   description           302 non-null    object
#  2   host_name             302 non-null    object
#  3   host_since            302 non-null    object
#  4   host_location         220 non-null    object
#  5   host_about            176 non-null    object
#  6   host_response_time    273 non-null    object
#  7   host_response_rate    273 non-null    object
#  8   host_acceptance_rate  278 non-null    object
#  9   host_verifications    302 non-null    object
#  10  property_type         302 non-null    object
#  11  room_type             302 non-null    object
#  12  accommodates          302 non-null    int64
#  13  bathrooms             0 non-null      float64
#  14  bathrooms_text        302 non-null    object
#  15  bedrooms              185 non-null    float64
#  16  beds                  299 non-null    float64
#  17  amenities             302 non-null    object
#  18  price                 302 non-null    object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 45.0+ KB

# %%
counter = {}

for i, row in df.iterrows():
    for amenity in eval(row['amenities']):
        if amenity in counter:
             counter[amenity] += 1
        else:
            counter[amenity] = 1
counter
# Out:
# {'Host greets you': 27,
#  'Baby safety gates': 11,
#  'Essentials': 269,
#  'Carbon monoxide alarm': 275,
#  'Pack ’n play/Travel crib': 44,
#  'Single level home': 67,
#  'Long term stays allowed': 172,
#  'Refrigerator': 230,
#  'Blender': 80,
#  'Dryer': 75,
#  'Coffee maker: Keurig coffee machine, pour-over coffee': 3,
#  'Iron': 221,
#  'Rice maker': 44,
#  'Hair dryer': 219,
#  'Drying rack for clothing': 27,
#  'Books and reading material': 71,
#  'Fire extinguisher': 256,
#  'Clothing storage: closet and dresser': 54,
#  'Luggage dropoff allowed': 97,
#  'Toaster': 162,
#  'Fireplace guards': 11,
#  'Microwave': 247,
#  'Freezer': 169,
#  'Portable fans': 88,
#  'Cooking basics': 229,
#  'Indoor fireplace: gas': 33,
#  'Extra pillows and blankets': 196,
#  'Barbecue utensils': 56,
#  'BBQ grill': 78,
#  'Kayak': 1,
#  'Body soap': 120,
#  'Smoke alarm': 301,
#  'Private backyard – Fully fenced': 67,
#  'Children’s dinnerware': 32,
#  'Stove': 78,
#  'TV': 120,
#  'First aid kit': 236,
#  'Free driveway parking on premises': 8,
#  'AC - split type ductless system': 27,
#  'Cleaning products': 179,
#  'Wine glasses': 162,
#  'Private entrance': 155,
#  'Private patio or balcony': 89,
#  'Shampoo': 191,
#  'Dishes and silverware': 260,
#  'Wifi': 252,
#  'Children’s books and toys': 39,
#  'Outdoor furniture': 125,
#  'Outdoor dining area': 95,
#  'Hangers': 259,
#  'Hot water': 245,
#  'Kitchen': 272,
#  'Washer': 114,
#  'Mini fridge': 43,
#  'Board games': 60,
#  'Dedicated workspace': 185,
#  'Outlet covers': 13,
#  'Dining table': 170,
#  'Bed linens': 234,
#  'Babysitter recommendations': 7,
#  'Hot water kettle': 114,
#  'Conditioner': 118,
#  'Ceiling fan': 84,
#  'Heating': 148,
#  'Coffee': 155,
#  'Fire pit': 46,
#  'Air conditioning': 115,
#  'Backyard': 56,
#  'Free parking on premises': 238,
#  'Pets allowed': 73,
#  'Free street parking': 188,
#  'Self check-in': 206,
#  'Breakfast': 24,
#  'Coffee maker': 125,
#  'TV with standard cable': 15,
#  'Patio or balcony': 36,
#  'Lockbox': 77,
#  'Security cameras on property': 138,
#  'Central air conditioning': 79,
#  'Fast wifi – 106 Mbps': 2,
#  'Oven': 128,
#  'Dishwasher': 167,
#  '55" HDTV with Apple TV, Netflix, Roku': 1,
#  'Bathtub': 136,
#  'Room-darkening shades': 116,
#  'Free dryer – In building': 23,
#  'Free washer – In building': 20,
#  'Cleaning available during stay': 41,
#  'Mrs. Meyers Clean Day body soap': 1,
#  'Central heating': 87,
#  'Indoor fireplace: electric': 24,
#  'Garden view': 40,
#  'Fast wifi – 265 Mbps': 1,
#  'BBQ grill: gas': 2,
#  'Shower gel': 104,
#  'HDTV with Amazon Prime Video, Netflix, Roku, standard cable': 1,
#  'Portable heater': 14,
#  'Free driveway parking on premises – 1 space': 9,
#  'Ethernet connection': 36,
#  'Clothing storage: walk-in closet': 6,
#  'Private sauna': 2,
#  'Trader Joes shampoo': 1,
#  'Coffee maker: Keurig coffee machine': 62,
#  'Trader Joes conditioner': 1,
#  '40" HDTV with Netflix': 1,
#  'Local hand crafted and anti-bacterial provided.  body soap': 1,
#  'Mini compact/no freezer refrigerator': 1,
#  'Shared backyard – Fully fenced': 18,
#  'Clothing storage: wardrobe': 3,
#  'Shared patio or balcony': 61,
#  'Laundromat nearby': 60,
#  'Fast wifi – 313 Mbps': 1,
#  'Window AC unit': 27,
#  'Baking sheet': 122,
#  'River view': 19,
#  '2 burner cooktop stove': 1,
#  'Combination microwave/convection oven': 1,
#  'Private backyard – Not fully fenced': 22,
#  'Children’s books and toys for ages 0-2 years old, 2-5 years old, and 5-10 years old': 2,
#  'Crib': 27,
#  'Lock on bedroom door': 76,
#  '55" HDTV with Roku': 5,
#  'Shared outdoor pool - available seasonally, open specific hours, pool toys': 3,
#  'Coffee maker: drip coffee maker, french press': 5,
#  'Shared BBQ grill: charcoal': 3,
#  'Piano': 17,
#  'Clothing storage: closet': 47,
#  'Smart lock': 55,
#  'Free dryer – In unit': 107,
#  'Keypad': 73,
#  'Clothing storage: dresser': 4,
#  'Private living room': 11,
#  '70" HDTV with premium cable, standard cable': 1,
#  'Indoor fireplace': 64,
#  'Free washer – In unit': 91,
#  'Liquid Body Soap body soap': 1,
#  'Radiant heating': 13,
#  'TV with Chromecast, Amazon Prime Video, Disney+, HBO Max, Netflix': 1,
#  'Ninja stainless steel oven': 1,
#  'Fast wifi – 438 Mbps': 1,
#  'Bluetooth sound system': 6,
#  'High chair': 29,
#  'Baby bath': 8,
#  'Waterfront': 19,
#  'Fast wifi – 108 Mbps': 1,
#  'One burner induction cooktop/pans stove': 1,
#  'Clothing storage: wardrobe and dresser': 1,
#  'Private backyard': 3,
#  'Park view': 7,
#  '14" TV': 1,
#  'Clothing storage': 29,
#  'Paid washer': 2,
#  'Canal view': 4,
#  'Oil of olé pump bath lotion body soap': 1,
#  'Fast wifi – 117 Mbps': 1,
#  'Electric stove': 44,
#  'Fast wifi – 78 Mbps': 1,
#  'Free parking on premises – 54 spaces': 1,
#  '55" HDTV with Amazon Prime Video, Disney+, HBO Max, Netflix': 1,
#  'Portable air conditioning': 26,
#  'Frigidaire electric stove': 5,
#  'HDTV with Amazon Prime Video, Chromecast, Disney+, HBO Max, Hulu, Netflix, DVD player': 1,
#  'Coffee maker: french press, Keurig coffee machine': 4,
#  'Indoor fireplace: wood-burning': 6,
#  'Wifi – 35 Mbps': 1,
#  'Sharp oven': 1,
#  '50" HDTV': 7,
#  'Clothing storage: walk-in closet, closet, and dresser': 7,
#  'Children’s books and toys for ages 5-10 years old': 1,
#  'Coffee maker: drip coffee maker': 29,
#  'Single oven': 7,
#  'Safe': 19,
#  'Hypoallergenic body soap': 1,
#  'LG Bluetooth sound system': 2,
#  'Record player': 8,
#  '55" HDTV with Amazon Prime Video, Disney+, Hulu, Netflix': 1,
#  'Exercise equipment: free weights, treadmill': 1,
#  '42" HDTV with Roku': 1,
#  'Fast wifi – 73 Mbps': 1,
#  'Free dryer': 2,
#  'Exercise equipment': 11,
#  'Shared backyard – Not fully fenced': 17,
#  'Gym': 2,
#  'Shared hot tub': 1,
#  'Smoking allowed': 8,
#  'Various body soap': 1,
#  '36" TV with standard cable': 1,
#  'Various shampoo': 1,
#  'Various conditioner': 1,
#  'Sun loungers': 8,
#  'Pool view': 4,
#  'Kirkland Signature and Others conditioner': 1,
#  'HDTV with standard cable': 2,
#  'Kirkland Signature and Others body soap': 1,
#  'Kirkland Signature and others conditioner': 1,
#  'Private BBQ grill: gas': 4,
#  'Kirkland Signature, other brands body soap': 1,
#  'Stainless steel oven': 34,
#  'Induction stove': 1,
#  'Game console': 10,
#  'EV charger': 9,
#  'Exercise equipment: free weights, stationary bike, yoga mat': 2,
#  'Fast wifi – 105 Mbps': 1,
#  'Bidet': 12,
#  '70" HDTV with Amazon Prime Video, Chromecast, HBO Max, Netflix, Roku, DVD player': 1,
#  'Courtyard view': 19,
#  '55" HDTV with Netflix, Amazon Prime Video': 1,
#  'Coffee maker: pour-over coffee': 6,
#  'Hot tub': 2,
#  'Dryer – In building': 2,
#  'Washer –\xa0In building': 2,
#  '45" HDTV with Amazon Prime Video, Netflix': 1,
#  'LG refrigerator': 1,
#  'Frigidaire  electric stove': 1,
#  'Surface shampoo': 1,
#  'Hammock': 15,
#  'Surface conditioner': 1,
#  'Dr. Bronners body soap': 1,
#  'Fast wifi – 86 Mbps': 1,
#  'Frigidaire  stainless steel oven': 1,
#  'Fast wifi – 122 Mbps': 1,
#  '32" HDTV with standard cable': 1,
#  'Pocket wifi': 2,
#  'Window guards': 3,
#  'HDTV with Netflix': 2,
#  'Exercise equipment: free weights, treadmill, yoga mat': 2,
#  'HDTV': 9,
#  'Clothing storage: walk-in closet and closet': 8,
#  'Private hot tub': 2,
#  'Gas stove': 17,
#  'Indoor fireplace: electric, wood-burning': 1,
#  'Private gym in building': 1,
#  'Paid washer – In building': 14,
#  '50" TV with Roku': 7,
#  'Paid dryer – In building': 18,
#  'HDTV with Netflix, Amazon Prime Video, Apple TV, HBO Max': 1,
#  'Magic Chef refrigerator': 1,
#  'Children’s books and toys for ages 0-2 years old and 2-5 years old': 2,
#  '40" HDTV with Roku': 1,
#  'Crib - always at the listing': 3,
#  'Heating - split type ductless system': 21,
#  'Clothing storage: walk-in closet and dresser': 4,
#  'Stainless steel electric stove': 5,
#  'Coffee maker: drip coffee maker, french press, Nespresso': 1,
#  'Wifi – 25 Mbps': 1,
#  'Satinique  shampoo': 1,
#  'G&H body soap': 1,
#  'Satinique  conditioner': 1,
#  '60" HDTV': 1,
#  'Pack ’n play/Travel crib - always at the listing': 7,
#  '52" TV with Roku': 1,
#  'TV with Netflix, Roku': 1,
#  'Induction Hot Plate electric stove': 1,
#  'Toaster Oven only stainless steel oven': 1,
#  'Valley view': 8,
#  'Mountain view': 7,
#  'Wella conditioner': 1,
#  'Beko (Gründig) stainless steel gas stove': 1,
#  '75" HDTV with standard cable': 1,
#  'Beko (Gründig) stainless steel oven': 1,
#  'Beko (Gründig) refrigerator': 1,
#  'Lily Farms Botanicals shampoo': 1,
#  '43" HDTV with Fire TV, standard cable, Netflix': 1,
#  'Lily Farms Botanicals conditioner': 1,
#  'Free residential garage on premises – 1 space': 3,
#  'Lily Farms Botanicals body soap': 1,
#  'Indoor fireplace: electric, gas': 1,
#  'Bread maker': 6,
#  'Coffee maker: drip coffee maker, Keurig coffee machine': 7,
#  'EV charger - level 2': 5,
#  'Private BBQ grill: charcoal, gas': 1,
#  'GE electric stove': 1,
#  'Game console: PS3': 3,
#  'Shower Dispenser conditioner': 1,
#  'Free driveway parking on premises – 2 spaces': 4,
#  'Shower Dispenser Installed:   Body Wash/Shampoo/Conditoner  body soap': 1,
#  '55" HDTV with standard cable': 2,
#  'Ge refrigerator': 2,
#  'Ge stainless steel oven': 1,
#  'Coffee maker: drip coffee maker, french press, Keurig coffee machine, pour-over coffee': 1,
#  '38" HDTV with Roku': 1,
#  'Suave conditioner': 1,
#  'City skyline view': 15,
#  'TV with Roku': 2,
#  '65" HDTV with Netflix': 1,
#  'Private outdoor pool - available seasonally, open 24 hours, heated': 1,
#  'Fast wifi – 62 Mbps': 1,
#  '50" HDTV with Amazon Prime Video, Chromecast, Netflix, Roku': 1,
#  'Shared pool': 2,
#  '48" HDTV': 1,
#  'LG Soundbar and Subwoofer Bluetooth sound system': 1,
#  'Coffee maker: drip coffee maker, pour-over coffee': 1,
#  'Stainless steel gas stove': 10,
#  'Paid parking on premises': 7,
#  'HDTV with Roku, Netflix, Hulu, HBO Max, premium cable, standard cable': 1,
#  'Large Convection/toaster oven stainless steel oven': 1,
#  'Compact (not mini) refrigerator': 1,
#  'Pool table': 3,
#  '32" HDTV with Roku': 1,
#  'Whirlpool refrigerator': 5,
#  'Wifi – 19 Mbps': 1,
#  'HDTV with Netflix, Hulu, Disney+, standard cable': 1,
#  'BBQ grill: charcoal': 2,
#  'Gas oven stainless steel oven': 1,
#  'Gas stove stainless steel stove': 1,
#  'Wifi – 37 Mbps': 1,
#  'TV with Netflix': 2,
#  'Puracy Natural Conditioner - Citrus & Mint conditioner': 1,
#  'Fast wifi – 360 Mbps': 1,
#  'Coffee maker: Keurig coffee machine, Nespresso': 1,
#  'Sound system': 2,
#  'Puracy Natural Shower Gel body soap': 1,
#  '55" HDTV with Chromecast, Disney+, HBO Max, Hulu, Netflix': 1,
#  'Puracy Natural Shampoo - Citrus & Mint shampoo': 1,
#  'Mini Fridge refrigerator': 1,
#  '55" HDTV with Netflix, Roku, standard cable': 4,
#  'Whirlpool stainless steel electric stove': 3,
#  'Fast wifi – 95 Mbps': 1,
#  'Aveda body soap': 1,
#  'Exercise equipment: yoga mat': 1,
#  'Mini fridge refrigerator': 1,
#  'Aveda conditioner': 1,
#  'Aveda shampoo': 1,
#  'Coffee maker: Nespresso': 2,
#  'TV with Hulu, Disney+, Roku, Amazon Prime Video, Netflix': 1,
#  'Fast wifi – 60 Mbps': 1,
#  'Children’s books and toys for ages 0-2 years old, 2-5 years old, 5-10 years old, and 10+ years old': 3,
#  '43" HDTV with Roku': 1,
#  'EV charger - level 1': 2,
#  '55" HDTV with Netflix, Roku': 1,
#  'Free carport on premises – 1 space': 1,
#  'EarthSuds conditioner': 1,
#  'EarthSuds body soap': 1,
#  'Good shampoo': 1,
#  'Good conditioner': 1,
#  'Ge oven': 2,
#  'Free driveway parking on premises – 3 spaces': 3,
#  'Trash compactor': 11,
#  '36" HDTV with Apple TV, standard cable': 1,
#  'HDTV with Disney+, Netflix, Roku': 1,
#  'Gas stainless steel oven': 1,
#  'Sub zero refrigerator': 1,
#  'Game console: Xbox 360': 2,
#  'Free washer': 1,
#  'ECO body soap': 1,
#  'Olay, Kirkland, or Dove shampoo': 1,
#  'Bikes': 4,
#  'Free parking on premises – 1 space': 5,
#  'SoundCore+ Bluetooth sound system': 2,
#  'Eco Botanics body soap': 1,
#  'Fast wifi – 352 Mbps': 1,
#  'Eco Botanics conditioner': 1,
#  'Outdoor shower': 2,
#  '30" TV': 1,
#  'HDTV with Amazon Prime Video, Disney+, HBO Max, Hulu, Netflix': 1,
#  '55" HDTV with Netflix, standard cable': 1,
#  'Whirlpool stainless steel stove': 1,
#  'Fast wifi – 429 Mbps': 1,
#  'Children’s books and toys for ages 2-5 years old and 5-10 years old': 1,
#  'AEG electric stove': 1,
#  'Vineyard view': 6,
#  '65" HDTV with Amazon Prime Video, Disney+, HBO Max, Hulu, Netflix': 1,
#  'Paid parking lot on premises': 2,
#  'BBQ grill: charcoal, gas': 1,
#  'Shared backyard': 3,
#  'Free parking garage on premises – 1 space': 1,
#  '50" HDTV with Netflix': 1,
#  '50" HDTV with Netflix, Roku': 5,
#  'Stainless steel induction stove': 2,
#  'Coffee maker: drip coffee maker, Keurig coffee machine, Nespresso': 1,
#  'Stainless steel stove': 7,
#  'HDTV with Amazon Prime Video, Disney+, Fire TV, Hulu, Netflix, Roku': 1,
#  '42" HDTV with Netflix': 1,
#  '70" HDTV with Fire TV': 1,
#  '51" HDTV': 2,
#  'Pack ’n play/Travel crib - available upon request': 3,
#  'TV with DVD player, Fire TV': 1,
#  'Coffee maker: espresso machine, french press, Keurig coffee machine': 1,
#  '55" HDTV': 4,
#  'HDTV with Hulu, Netflix': 1,
#  'Samsung refrigerator': 3,
#  'Samsung stainless steel oven': 1,
#  'Exercise equipment: stationary bike': 1,
#  'Free carport on premises – 2 spaces': 1,
#  'Mosquito net': 3,
#  '65" HDTV with Roku': 3,
#  'Dove body soap': 5,
#  '45" TV with Roku': 2,
#  'Other electric stove': 1,
#  'LG Sound Bar sound system with Bluetooth and aux': 1,
#  'Shared outdoor pool - available seasonally, open specific hours': 2,
#  'Whirlpool stainless steel gas stove': 1,
#  'Whirlpool stainless steel oven': 2,
#  'Fast wifi – 110 Mbps': 1,
#  'GE stainless steel oven': 1,
#  'LG SoundBar sound system with Bluetooth and aux': 1,
#  'Slab (handcrafted in Oregon) body soap': 1,
#  'Coffee maker: drip coffee maker, french press, pour-over coffee': 2,
#  '32" HDTV': 1,
#  '32" TV with standard cable, HBO Max, Amazon Prime Video, Netflix, Disney+, Fire TV': 1,
#  '32" TV with Amazon Prime Video, Fire TV, HBO Max, Netflix': 1,
#  'Crib - available upon request': 1,
#  '42" HDTV': 1,
#  'Paid dryer': 1,
#  'Fast wifi – 153 Mbps': 1,
#  'Coffee maker: french press, Keurig coffee machine, pour-over coffee': 1,
#  '65" HDTV with Apple TV, Chromecast, Disney+, HBO Max, Hulu, Netflix, Roku, DVD player': 1,
#  'Everyone: 3 in 1 Body wash, shampoo, and bubble bath body soap': 1,
#  'Everyone: 3 in 1 Body wash/shampoo/bubble bath and Head and Shoulders shampoo/conditioner shampoo': 1,
#  'Dispenses filtered water and ice cubes refrigerator': 1,
#  'Fast wifi – 453 Mbps': 1,
#  'Fast wifi – 361 Mbps': 1,
#  'Luseta  shampoo': 1,
#  'Luseta  conditioner': 1,
#  'Body wash and bar soap are available on the guest hanger under shower head. body soap': 1,
#  '50" HDTV with Roku': 4,
#  'Fast wifi – 57 Mbps': 1,
#  'Fast wifi – 80 Mbps': 1,
#  "Tresemme' shampoo": 1,
#  'Children’s books and toys for ages 2-5 years old': 1,
#  'Suave body wash body soap': 1,
#  '45" HDTV with Amazon Prime Video, Hulu, Netflix, Roku': 1,
#  '56" HDTV with standard cable': 1,
#  '32" TV with Roku': 6,
#  '40" HDTV with standard cable': 1,
#  'Fast wifi – 259 Mbps': 1,
#  'Stainless steel single oven': 1,
#  'Ping pong table': 1,
#  'Clothing storage: closet, wardrobe, and dresser': 2,
#  'Outdoor kitchen with sink': 1,
#  'Fast wifi – 50 Mbps': 1,
#  'Everyone - All Natural Plant Based shampoo': 1,
#  'GE stainless steel electric stove': 1,
#  'GE stainless steel single oven': 1,
#  'Everyone - All Natural Plant Based conditioner': 1,
#  'Everyone - All Natural Plant Based body soap': 1,
#  '55" HDTV with Apple TV': 1,
#  'LG Hi-Fi Sounder w/ Subwoofer sound system with Bluetooth and aux': 1,
#  'Fast wifi – 571 Mbps': 1,
#  'Fast wifi – 580 Mbps': 1,
#  'HDTV with Roku': 2,
#  'Fast wifi – 579 Mbps': 1,
#  'Fast wifi – 230 Mbps': 1,
#  'Fast wifi – 129 Mbps': 1,
#  'Clothing storage: closet and wardrobe': 1,
#  'Pro formular shampoo': 1,
#  'Ivory body soap': 1,
#  'Blonde conditioner': 1,
#  'Magic chef refrigerator': 1,
#  'Table corner guards': 2,
#  'Children’s books and toys for ages 2-5 years old, 5-10 years old, and 10+ years old': 2,
#  'Samsung  refrigerator': 1,
#  '50" HDTV with Chromecast, Disney+, Hulu, Netflix, Roku, DVD player': 1,
#  'Fast wifi – 257 Mbps': 1,
#  'Samsung stainless steel electric stove': 3,
#  'Samsung  stainless steel oven': 1,
#  'Folding or convertible high chair': 1,
#  'Fast wifi – 184 Mbps': 1,
#  '65" HDTV with Amazon Prime Video, HBO Max, Netflix': 1,
#  'Sound system with Bluetooth and aux': 1,
#  'Private outdoor kitchen': 2,
#  'Game console: Nintendo Wii, PS2, PS3, PS4, and PS5': 1,
#  '65" HDTV with Amazon Prime Video, HBO Max, Netflix, Roku, standard cable, DVD player': 1,
#  'Standalone high chair - available upon request': 1,
#  'Paid crib - available upon request': 1,
#  'Private BBQ grill: electric, gas, wood-burning': 1,
#  'Free driveway parking on premises – 4 spaces': 1,
#  'Herbal essences conditioner': 1,
#  '70" HDTV with Amazon Prime Video, Apple TV, Disney+, Hulu, Netflix, Roku, DVD player': 1,
#  'Herbal essences shampoo': 1,
#  '55" TV': 1,
#  '32" HDTV with Amazon Prime Video, Apple TV, Disney+, Fire TV, HBO Max, Hulu, Netflix, DVD player': 1,
#  'Private outdoor pool - available all year, open 24 hours': 1,
#  'Private hot tub - available all year, open 24 hours': 1,
#  '30" TV with Hulu, Fire TV, Amazon Prime Video, Netflix': 1,
#  'Fast wifi – 441 Mbps': 1,
#  'Fast wifi – 427 Mbps': 1,
#  'Fridgidare oven': 1,
#  'Clothing storage: walk-in closet, closet, wardrobe, and dresser': 1,
#  'Ski-in/Ski-out': 1,
#  'Paid washer – In unit': 1,
#  'Coffee maker: espresso machine': 2,
#  'Fast wifi – 82 Mbps': 1,
#  'Free carport on premises': 1,
#  'Whirlpool  refrigerator': 1,
#  'Shared gym nearby': 1,
#  'Whirlpool electric stove': 1,
#  'Whirlpool  single oven': 1,
#  '65" HDTV with Amazon Prime Video, Apple TV, Disney+, HBO Max, Hulu, Netflix': 1,
#  'Samsung stainless steel single oven': 1,
#  'Fast wifi – 115 Mbps': 1,
#  '55" HDTV with Hulu, Amazon Prime Video, Disney+, Netflix': 1,
#  'GE gas stove': 1,
#  'GE CAFE stainless steel oven': 1,
#  'GE CAFE refrigerator': 1,
#  'Folding or convertible high chair - always at the listing': 1,
#  'Stainless steel double oven': 1,
#  '32" TV': 1,
#  'Private BBQ grill: charcoal': 1,
#  'Automatic Ice Maker refrigerator': 1,
#  'Samsung  stainless steel single oven': 1,
#  'Wifi – 47 Mbps': 1,
#  'Coffee maker: french press': 1,
#  'Ginger Lily Farms shampoo': 1,
#  'Ginger Lily Farms conditioner': 1,
#  'Ginger Lily Farms body soap': 1,
#  'GE single oven': 1,
#  '45" HDTV': 1,
#  'Coffee maker: french press, pour-over coffee': 1,
#  'Dove  conditioner': 1,
#  'Whirlpool double oven': 1,
#  'Changing table': 2,
#  'Bay view': 3,
#  'Dove shampoo': 1,
#  'Resort access': 3,
#  'Elevator': 1,
#  'Kirkland conditioner': 1,
#  'Kirkland shampoo': 1,
#  'Kirkland body soap': 1,
#  '56" HDTV with Apple TV, Netflix': 1,
#  'Building staff': 1,
#  'Indoor fireplace: pellet stove': 1,
#  'HDTV with Amazon Prime Video, Disney+, Hulu, Netflix': 1,
#  'Fast wifi – 340 Mbps': 1,
#  'Kitchenette': 1,
#  'Backyard - Fully fenced': 1}

# %% [markdown]
# To make this analysis even easier to read, let's loop through each amenity in the counter and only print out the ones that have more than 200 occurences.

# %%
for amenity in counter:
    if counter[amenity] > 200:
        print(amenity, counter[amenity])
# Out:
# Essentials 269
# Carbon monoxide alarm 275
# Refrigerator 230
# Iron 221
# Hair dryer 219
# Fire extinguisher 256
# Microwave 247
# Cooking basics 229
# Smoke alarm 301
# First aid kit 236
# Dishes and silverware 260
# Wifi 252
# Hangers 259
# Hot water 245
# Kitchen 272
# Bed linens 234
# Free parking on premises 238
# Self check-in 206

# %% [markdown]
# ## Conclusion
# Out of the 302 Airbnb listings, here are the most common amenities:
#
# `Essentials,
# Carbon monoxide alarm,
# Refrigerator,
# Iron,
# Hair dryer,
# Fire extinguisher,
# Microwave,
# Cooking basics,
# Smoke alarm,
# First aid kit,
# Dishes and silverware,
# Wifi,
# Hangers,
# Hot water,
# Kitchen,
# Bed linens,
# Free parking on premises,
# Self check-in`
#
# While not every listing will have all of these items, you'd be hard pressed to find listings without a lot of these.
